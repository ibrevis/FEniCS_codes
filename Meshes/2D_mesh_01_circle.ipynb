# %%
import fenics as fn
import mshr
#
import numpy as np
#
from matplotlib import pyplot as plt

# %%
geometry = mshr.Circle(fn.Point(1,1),1)
mesh = mshr.generate_mesh(geometry, 16)

# %%
fn.plot(mesh)
plt.show()

# %%
np.shape(mesh.coordinates()[:])
# Out:
# (562, 2)
